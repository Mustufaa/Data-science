# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import  pandas as pd

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
'''c1.plotly_chart(fig1)
c2.plotly_chart(fig2)

fig3=px.box(df, x=scat_col, y=snum_col, title=f'{snum_col} by {scat_col}')
st.plotly_chart(fig3)

fig4=px.treemap(
    df,
    path=['Generation','Type 1'],
    title=f'Pokemon Type Distribution'
)
st.plotly_chart(fig4)
# to run this program, open terminal and run the following command
# streamlit run app.py '''

# %%
fig, ax = plt.subplots(figsize=(12, 6))
titanic = pd.DataFrame({
      'class': ['First', 'Second', 'Third', 'First', 'Third', 'Second', 'Third', 'First']})
#titanic=pd.DataFrame({'class'}.values())
sns.countplot(data=titanic,x='class',ax=ax, palette='Set1')
ax.set_xlabel('Class')
ax.set_ylabel('Count')
ax.set_title('Count of Each Class')
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_3400\2206144391.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=titanic,x='class',ax=ax, palette='Set1')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example DataFrame (replace this with your actual DataFrame)
titanic = pd.DataFrame({
    'Class': ['First', 'Second', 'Third', 'First', 'Third', 'Second', 'Third', 'First']
})

# Count occurrences of each class
count = titanic['Class'].value_counts()

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Define the class names and colors
classes = ['First', 'Second', 'Third']
colors = ['yellow', 'blue', 'green']

# Plot the bar chart
# Ensure that all classes are accounted for, even if some have a count of 0
bar_counts = [count.get(c, 0) for c in classes]
ax.bar(classes, bar_counts, color=colors)

# Add labels and title (optional)
ax.set_xlabel('Class')
ax.set_ylabel('Count')
ax.set_title('Count of Each Class')

# Show the plot
plt.show()

# %%
px.sunburst(
    data_frame=titanic,
    path=['day','time','sex','smoker'],
    values='tip'
)
